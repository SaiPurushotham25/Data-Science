# %%
from matplotlib import pyplot as plt
from matplotlib import style 
import seaborn as sns
# %matplotlib inline
import pandas as pd

# %%
# !pip install seaborn

# %%
df=pd.read_excel("D:\\python\\Global Superstore.xls")

# %%
df
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
sns.lmplot(y="Profit",x="Discount",data=df)
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(y="Sales",x="Quantity",data=df)
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(y="Sales",x="Discount",data=df)
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(data=df[["Sales","Profit","Quantity","Discount","Shipping Cost"]])
# Out:
# <Axes: >

# %%
sns.lmplot(y="Profit",x="Quantity",data=df)
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(data=df[["Profit"]])
# Out:
# <Axes: >

# %%
df_num=df[["Sales","Profit","Discount","Quantity","Shipping Cost"]]
sns.heatmap(df_num.corr())
# Out:
# <Axes: >

# %%
df_num=df[["Profit","Discount"]]
sns.heatmap(df_num.corr())
# Out:
# <Axes: >

# %%
sns.countplot(x="Discount",data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='count'>

# %%
sns.displot(df["Discount"])
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df["Profit"])
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_num=df[["Sales","Profit","Discount","Quantity","Shipping Cost"]]
sns.pairplot(df_num)
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(data=df[["Sales"]])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[["Quantity"]])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[["Shipping Cost"]])
# Out:
# <Axes: >

# %%
sns.countplot(x="Profit",data=df)
# Out:
# <Axes: xlabel='Profit', ylabel='count'>

# %%
sns.countplot(x="Quantity",data=df)
# Out:
# <Axes: xlabel='Quantity', ylabel='count'>

# %%
sns.countplot(x="Shipping Cost",data=df)
# Out:
# <Axes: xlabel='Shipping Cost', ylabel='count'>

# %%
sns.displot(df["Profit"])
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df["Sales"])
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df["Quantity"])
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df["Shipping Cost"])
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
